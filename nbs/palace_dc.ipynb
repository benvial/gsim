# %% [markdown]
# # Palace Directional Coupler Simulation - Wave Ports
#
# This notebook mirrors the geometry in [meep_dc.ipynb](meep_dc.ipynb), but configures a Palace driven simulation with waveport boundary conditions.
#
# MEEP-specific features (for example FDTD PML/animation details) are omitted.

# %% [markdown]
# ### Load the same directional coupler geometry

# %%
from pathlib import Path

import gdsfactory.component as gfc
from ubcpdk import PDK, cells

# Use a workspace-local temp path for layer preview artifacts.
gds_tmp = Path.cwd() / ".gdsfactory_tmp"
gds_tmp.mkdir(parents=True, exist_ok=True)
gfc.GDSDIR_TEMP = gds_tmp

PDK.activate()

c = cells.coupler()

cc = c.copy()
cc.draw_ports()
cc

# %% [markdown]
# ### Configure Palace driven simulation with waveports

# %%
from gsim.palace import DrivenSim

sim = DrivenSim()
sim.set_output_dir("./palace-sim-dc-waveport")
sim.set_geometry(c)

sim.set_stack(
    substrate_thickness=2.0,
    add_oxide_dielectric=False,
    add_passivation_dielectric=False,
)

# Use direct sparse solve backend.
sim.set_numerical(
    solver_type="MUMPS",
    max_iterations=1,
    tolerance=1e-8,
)

for i, port in enumerate(c.ports):
    sim.add_wave_port(
        str(port.name),
        layer="core",
        z_margin=1.5,
        lateral_margin=1.5,
        max_size=False,
        mode=1,
        excited=(i == 0),
    )

# Around 1.55 um (~193.5 THz).
sim.set_driven(fmin=190e12, fmax=200e12, num_points=21)

print(sim.validate_config())
# Out:
# Validation: PASSED

# %%
import gdsfactory as gf

active = gf.get_active_pdk()
print("Active PDK:", active.name)

stack = sim._resolve_stack()
print("Stack layers:")
for name, layer in stack.layers.items():
    print(
        f"  - {name}: type={layer.layer_type}, material={layer.material}, "
        f"gds={tuple(layer.gds_layer)}, z=({layer.zmin}, {layer.zmax})"
    )

print("\nMaterial properties (selected):")
for key in ("si", "sio2", "SiO2", "air"):
    if key in stack.materials:
        print(f"  - {key}: {stack.materials[key]}")

print("\nDielectric regions:")
for d in stack.dielectrics:
    print(f"  - {d}")
# Out:
# Active PDK: ubcpdk
# Stack layers:
#   - box: type=dielectric, material=sio2, gds=(999, 0), z=(-3.0, 0.0)
#   - clad: type=dielectric, material=sio2, gds=(999, 0), z=(0.0, 1.8000000000000003)
#   - core: type=dielectric, material=si, gds=(1, 0), z=(0.0, 0.22)
#   - core2: type=dielectric, material=si, gds=(31, 0), z=(0.0, 0.22)
#   - heater: type=conductor, material=TiN, gds=(11, 0), z=(1.1, 1.85)
#   - metal2: type=conductor, material=Aluminum, gds=(12, 0), z=(1.8000000000000003, 2.5000000000000004)
#
# Material properties (selected):
#   - si: {'type': 'semiconductor', 'conductivity': 2.0, 'permittivity': 11.9, 'refractive_index': 3.47}
#   - sio2: {'type': 'dielectric', 'permittivity': 4.1, 'loss_tangent': 0.0, 'refractive_index': 1.44}
#   - SiO2: {'type': 'dielectric', 'permittivity': 4.1, 'loss_tangent': 0.0, 'refractive_index': 1.44}
#   - air: {'type': 'dielectric', 'permittivity': 1.0, 'loss_tangent': 0.0, 'refractive_index': 1.0}
#
# Dielectric regions:

# %% [markdown]
# ### Generate mesh

# %%
sim.set_airbox(
    margin_x=0.0,
    margin_y=1.5,
    margin_above=0.5,
    margin_below=0.5,
)

# fmax=220 THz -> lambda0~1.36 um. In Si (n~3.45), lambda~0.395 um,
# so for >=5 points per wavelength use mesh size <=0.079 um.
sim.mesh(
    preset="fine",
    refined_mesh_size=0.1,
    max_mesh_size=0.5,
    fmax=220e12,
    curve_fit_mode="bspline",
    curve_fit_layers=["core", "core2"],
    curve_fit_tolerance_um=0.01,
    curve_fit_min_points=8,
    high_order_elements=True,
    high_order_order=2,
    high_order_optimize=True,
)
# Out:
# Mesh Summary
# ========================================
# Dimensions: 34.5 x 7.5 x 6.5 µm
# Nodes:      163,038
# Elements:   138,689
# ----------------------------------------
# Volumes (2):
#   - core [1]
#   - airbox [2]
# Surfaces (6):
#   - P1 [3]
#   - P2 [4]
#   - P3 [5]
#   - P4 [6]
#   - airbox__core [7]
#   - airbox__None [8]
# ----------------------------------------
# Mesh:   palace-sim-dc-waveport/palace.msh

# %%
sim.plot_mesh(
    style="solid",
    transparent_groups=["airbox__None"],
    interactive=True,
)
# Out:
# Widget(value='<iframe src="http://localhost:44175/index.html?ui=P_0x7ac286191c70_0&reconnect=auto" class="pyvi…

# %% [markdown]
# ### Run simulation

# %%
for p in sim._last_mesh_result.port_info:
    print(
        f"{p['type']} P{p['portnumber']}: "
        f"z=({p['zmin']:.3f}, {p['zmax']:.3f}), "
        f"x=({p['xmin']:.3f}, {p['xmax']:.3f}), "
        f"y=({p['ymin']:.3f}, {p['ymax']:.3f})"
    )
# Out:
# waveport P1: z=(-1.500, 1.720), x=(-10.000, -10.000), y=(-3.400, 0.100)
# waveport P2: z=(-1.500, 1.720), x=(-10.000, -10.000), y=(0.600, 4.100)
# waveport P3: z=(-1.500, 1.720), x=(24.500, 24.500), y=(0.600, 4.100)
# waveport P4: z=(-1.500, 1.720), x=(24.500, 24.500), y=(-3.400, 0.100)

# %%
import json
from pathlib import Path

# For photonic sims, bypass conductor-oriented mesh validation.
config_path = sim.write_config(photonic=True)
cfg = json.loads(Path(config_path).read_text())
print("Solver.Linear:", cfg["Solver"]["Linear"])

results = sim.run_local(num_processes=16, verbose=True)
# Out:
# Running Palace simulation in palace-sim-dc-waveport via Apptainer
# Command: apptainer run /home/martin/Desktop/palace/Palace.sif -np 16 config.json
# Processes: 16
# >> /usr/lib64/mpich/bin/mpirun -n 16 /opt/palace/bin/palace-x86_64.bin config.json
# Solver.Linear: {'Type': 'MUMPS', 'KSPType': 'GMRES', 'Tol': 1e-08, 'MaxIts': 1, 'MGMaxLevels': 1, 'EstimatorMaxIts': 0, 'EstimatorTol': 1e-06, 'DivFreeTol': 1e-06, 'DivFreeMaxIts': 0, 'PCMatReal': False, 'ComplexCoarseSolve': True}
# _____________     _______
# _____   __   \____ __   /____ ____________
# ____   /_/  /  __ ` /  /  __ ` /  ___/  _ \
# ___   _____/  /_/  /  /  /_/  /  /__/  ___/
#   /__/     \___,__/__/\___,__/\_____\_____/
# --> Warning!
# Output folder is not empty; program will overwrite content! (output/palace)
# Git changeset ID: v0.14.0-305-g51d61b03
# Running with 16 MPI processes, 1 OpenMP thread
# Device configuration: omp,cpu
# Memory configuration: host-std
# libCEED backend: /cpu/self/xsmm/blocked
# Finished partitioning mesh into 16 subdomains
# Characteristic length and time scales:
#  L₀ = 3.450e-05 m, t₀ = 1.151e-04 ns
# Mesh curvature order: 2
# Mesh bounding box:
#  (Xmin, Ymin, Zmin) = (-1.000e-05, -3.400e-06, -3.500e-06) m
#  (Xmax, Ymax, Zmax) = (+2.450e-05, +4.100e-06, +3.000e-06) m
# Parallel Mesh Stats:
#                 minimum     average     maximum       total
#  vertices          1047        1388        1760       22213
#  edges             7620        8756        9686      140097
#  faces            13376       14248       14810      227976
#  elements          6776        6880        7038      110091
#  neighbors            2           4           5
#             minimum     maximum
#  h       0.00138425   0.0243975
#  kappa        1.065     136.353
# Configuring Robin absorbing BC (order 2) at attributes:
#  8
# Configuring Robin impedance BC for wave ports at attributes:
#  3: Index = 1, mode = 1, d = 0.000e+00 m,  n = (-1.0,-0.0,-0.0)
#  4: Index = 2, mode = 1, d = 0.000e+00 m,  n = (-1.0,-0.0,-0.0)
#  5: Index = 3, mode = 1, d = 0.000e+00 m,  n = (+1.0,+0.0,-0.0)
#  6: Index = 4, mode = 1, d = 0.000e+00 m,  n = (+1.0,+0.0,-0.0)
# Configuring wave port excitation source term at attributes:
#  3: Index = 1
# Computing adaptive fast frequency response for:
# Excitation with index 1 has contributions from:
#  Wave port  1
# Beginning PROM construction offline phase:
#  21 points for frequency sweep over [1.900e+04, 2.000e+04] GHz
# Assembling system matrices, number of global unknowns:
#  H1 (p = 1): 22213, ND (p = 1): 140097, RT (p = 1): 227976
#  Operator assembly level: Partial
#  Mesh geometries:
#   Tetrahedron: P = 6, Q = 4 (quadrature order = 2)
# Assembling multigrid hierarchy:
#  Level 0 (p = 1): 140097 unknowns
#  Level 0 (auxiliary) (p = 1): 22213 unknowns
# Entering DMUMPS 5.7.3 from C interface with JOB, N =   1      280194
#       executing #MPI =     16 and #OMP =      1
#  =================================================
#  MUMPS compiled with option -DGEMMT_AVAILABLE
#  MUMPS compiled with option -Dmetis
#  MUMPS compiled with option -Dparmetis
#  MUMPS compiled with option -Dpord
#  =================================================
# L U Solver for unsymmetric matrices
# Type of parallelism: Working host
#  ****** ANALYSIS STEP ********
#  ** Maximum transversal (ICNTL(6)) not allowed because matrix is distributed
#  Processing a graph of size:    280194 with       8393802 edges
#  Ordering based on METIS
#  ELAPSED TIME SPENT IN METIS reordering  =      1.4906
#  SYMBOLIC based on column counts
#  ELAPSED TIME IN symbolic factorization  =      0.0888
#  A root of estimated size         1094  has been selected for Scalapack.
# Leaving analysis phase with  ...
#  INFOG(1)                                       =               0
#  INFOG(2)                                       =               0
#  -- (20) Number of entries in factors (estim.)  =       230145188
#  --  (3) Real space for factors    (estimated)  =       230379410
#  --  (4) Integer space for factors (estimated)  =         3284452
#  --  (5) Maximum frontal size      (estimated)  =            3656
#  --  (6) Number of nodes in the tree            =            9764
#  -- (32) Type of analysis effectively used      =               1
#  --  (7) Ordering option effectively used       =               5
#  ICNTL (6) Maximum transversal option           =               0
#  ICNTL (7) Pivot order option                   =               7
#  ICNTL(12) Ordering symmetric indef. matrices   =               1
#  ICNTL(13) Parallelism/splitting of root node   =               0
#  ICNTL(14) Percentage of memory relaxation      =              20
#  ICNTL(15) Analysis by block effectively used   =               0
#  ICNTL(18) Distributed input matrix (on if >0)  =               3
#  ICNTL(32) Forward elimination during facto.    =               0
#  ICNTL(35) BLR activation                       =               0
#  ICNTL(48) Tree based multithreading (effective)=               0
#  ICNTL(58) Symbolic factorization option        =               2
#  Number of level 2 nodes                        =              40
#  Number of split nodes                          =              14
#  RINFOG(1) Operations during elimination (estim)= 3.056D+11
#  Distributed matrix entry format (ICNTL(18))    =               3
#  MEMORY ESTIMATIONS ...
#  Estimations with standard Full-Rank (FR) factorization:
#     Maximum estim. space in Mbytes, IC facto.    (INFOG(16)):             296
#     Total space in MBytes, IC factorization      (INFOG(17)):            4256
#     Maximum estim. space in Mbytes, OOC facto.   (INFOG(26)):             182
#     Total space in MBytes,  OOC factorization    (INFOG(27)):            2702
#  Elapsed time in analysis driver=       1.7947
# Entering DMUMPS 5.7.3 from C interface with JOB, N =   2      280194
#       executing #MPI =     16 and #OMP =      1
# ****** FACTORIZATION STEP ********
#  GLOBAL STATISTICS PRIOR NUMERICAL FACTORIZATION ...
#  Number of working processes                =              16
#  ICNTL(22) Out-of-core option               =               0
#  ICNTL(35) BLR activation (eff. choice)     =               0
#  ICNTL(37) BLR CB compression (eff. choice) =               0
#  ICNTL(49) Compact workarray S (end facto.) =               0
#  ICNTL(14) Memory relaxation                =              20
#  INFOG(3) Real space for factors (estimated)=       230379410
#  INFOG(4) Integer space for factors (estim.)=         3284452
#  Maximum frontal size (estimated)           =            3656
#  Number of nodes in the tree                =            9764
#  ICNTL(23) Memory allowed (value on host)   =               0
#            Sum over all procs               =               0
#  Memory provided by user, sum of LWK_USER   =               0
#  Effective threshold for pivoting, CNTL(1)  =      0.1000D-01
#  Statistics on the scaling phase
#  Elapsed time for scaling                   =      0.0649
#  Max difference from 1 after scaling the entries for ONE-NORM (option 7/8)   = 0.12D+00
#  Average Effective size of S     (based on INFO(39))=             21247472
#  Redistrib: total data local/sent           =          133265        10109161
#  Elapsed time to reformat/distribute matrix =      0.0511
#  Allocated buffers
#  ------------------
#  Size of reception buffer in bytes ...... =      5325052
#  Size of async. emission buffer (bytes).. =     10703352
#  Small emission buffer (bytes) .......... =         6720
#  ** Memory allocated, max in Mbytes             (INFOG(18)):         296
#  ** Memory allocated, total in Mbytes           (INFOG(19)):        4256
#  ** Memory effectively used, max in  Mbytes     (INFOG(21)):         260
#  ** Memory effectively used, total in Mbytes    (INFOG(22)):        3808
#  Elapsed time to process root node                  =      0.0896
#  Elapsed time for factorization                     =      1.7948
# Leaving factorization with ...
#  RINFOG (2) Operations in node assembly             = 5.032D+08
#  ------ (3) Operations in node elimination          = 3.056D+11
#  ICNTL  (8) Scaling effectively used                =               7
#  INFOG  (9) Real space for factors                  =       230145188
#  INFOG (10) Integer space for factors               =         3274455
#  INFOG (11) Maximum front size                      =            3656
#  INFOG (29) Number of entries in factors            =       230145188
#  INFOG (12) Number of off diagonal pivots           =             318
#  INFOG (13) Number of delayed pivots                =               0
#  RINFOG(19) Smallest pivot WITH perturbed pivots    = 7.230D-06
#  RINFOG(20) Smallest pivot WITHOUT perturbed pivots = 7.230D-06
#  RINFOG(21) Largest pivot in absolute value         = 6.359D+01
#  INFOG (24) Effective value of ICNTL(12)            =               1
#  INFOG (14) Number of memory compress               =              33
#  Elapsed time in factorization driver               =      1.9157
# Residual norms for GMRES solve
# Entering DMUMPS 5.7.3 from C interface with JOB, N =   3      280194
#       executing #MPI =     16 and #OMP =      1
#  ****** SOLVE & CHECK STEP ********
#  GLOBAL STATISTICS PRIOR SOLVE PHASE ...........
#  Number of right-hand-sides                    =           1
#  Blocking factor for multiple rhs              =           1
#  ICNTL (9)                                     =           1
#   --- (10)                                     =           0
#   --- (11)                                     =           0
#   --- (20)                                     =          10
#   --- (21)                                     =           1
#   --- (30)                                     =           0
#   --- (35)                                     =           0
#   --- (48) (effective)                         =           0
#  ** Rank of processor needing largest memory in solve     :        14
#  ** Space in MBYTES used by this processor for solve      :       225
#  ** Avg. Space in MBYTES per working proc during solve    :       197
#  Leaving solve with ...
#  Time to build/scatter RHS        =       0.001047
#  Time in solution step (fwd/bwd)  =       0.059091
#   .. Time in forward (fwd) step   =          0.026564
#   .. Time in ScaLAPACK root       =          0.004938
#   .. Time in backward (bwd) step  =          0.027565
#  Time to gather solution(cent.sol)=       0.000000
#  Time for distributed solution    =       0.000703
#  Elapsed time in solve driver=       0.0655
# 0 (restart 0) KSP residual norm 2.049564e+01
# Entering DMUMPS 5.7.3 from C interface with JOB, N =   3      280194
#       executing #MPI =     16 and #OMP =      1
#  ****** SOLVE & CHECK STEP ********
#  GLOBAL STATISTICS PRIOR SOLVE PHASE ...........
#  Number of right-hand-sides                    =           1
#  Blocking factor for multiple rhs              =           1
#  ICNTL (9)                                     =           1
#   --- (10)                                     =           0
#   --- (11)                                     =           0
#   --- (20)                                     =          10
#   --- (21)                                     =           1
#   --- (30)                                     =           0
#   --- (35)                                     =           0
#   --- (48) (effective)                         =           0
#  ** Rank of processor needing largest memory in solve     :        14
#  ** Space in MBYTES used by this processor for solve      :       225
#  ** Avg. Space in MBYTES per working proc during solve    :       197
#  Leaving solve with ...
#  Time to build/scatter RHS        =       0.001196
#  Time in solution step (fwd/bwd)  =       0.051142
#   .. Time in forward (fwd) step   =          0.025570
#   .. Time in ScaLAPACK root       =          0.000845
#   .. Time in backward (bwd) step  =          0.024712
#  Time to gather solution(cent.sol)=       0.000000
#  Time for distributed solution    =       0.000480
#  Elapsed time in solve driver=       0.0578
# 1 (restart 0) KSP residual norm 6.438893e-12
# GMRES solver converged in 1 iteration (avg. reduction factor: 3.142e-13)
#  Field energy E (5.170e-05 J) + H (1.909e-05 J) = 7.078e-05 J
# PCG solver did NOT converge in 0 iterations
# --> Warning!
# Linear solver did not converge, norm(Ax-b)/norm(b) = 1.000e+00 (norm(b) = 9.258e-01)!
# PCG solver did NOT converge in 0 iterations
# --> Warning!
# Linear solver did not converge, norm(Ax-b)/norm(b) = 1.000e+00 (norm(b) = 4.606e-01)!
# Entering DMUMPS 5.7.3 from C interface with JOB, N =   2      280194
#       executing #MPI =     16 and #OMP =      1
# ****** FACTORIZATION STEP ********
#  GLOBAL STATISTICS PRIOR NUMERICAL FACTORIZATION ...
#  Number of working processes                =              16
#  ICNTL(22) Out-of-core option               =               0
#  ICNTL(35) BLR activation (eff. choice)     =               0
#  ICNTL(37) BLR CB compression (eff. choice) =               0
#  ICNTL(49) Compact workarray S (end facto.) =               0
#  ICNTL(14) Memory relaxation                =              20
#  INFOG(3) Real space for factors (estimated)=       230379410
#  INFOG(4) Integer space for factors (estim.)=         3284452
#  Maximum frontal size (estimated)           =            3656
#  Number of nodes in the tree                =            9764
#  ICNTL(23) Memory allowed (value on host)   =               0
#            Sum over all procs               =               0
#  Memory provided by user, sum of LWK_USER   =               0
#  Effective threshold for pivoting, CNTL(1)  =      0.1000D-01
#  Statistics on the scaling phase
#  Elapsed time for scaling                   =      0.0646
#  Max difference from 1 after scaling the entries for ONE-NORM (option 7/8)   = 0.12D+00
#  Average Effective size of S     (based on INFO(39))=             21247472
#  Redistrib: total data local/sent           =          133265        10109161
#  Elapsed time to reformat/distribute matrix =      0.0425
#  Allocated buffers
#  ------------------
#  Size of reception buffer in bytes ...... =      5325052
#  Size of async. emission buffer (bytes).. =     10703352
#  Small emission buffer (bytes) .......... =         6720
#  ** Memory allocated, max in Mbytes             (INFOG(18)):         296
#  ** Memory allocated, total in Mbytes           (INFOG(19)):        4254
#  ** Memory effectively used, max in  Mbytes     (INFOG(21)):         259
#  ** Memory effectively used, total in Mbytes    (INFOG(22)):        3807
#  Elapsed time to process root node                  =      0.0063
#  Elapsed time for factorization                     =      1.6115
# Leaving factorization with ...
#  RINFOG (2) Operations in node assembly             = 5.032D+08
#  ------ (3) Operations in node elimination          = 3.056D+11
#  ICNTL  (8) Scaling effectively used                =               7
#  INFOG  (9) Real space for factors                  =       230145188
#  INFOG (10) Integer space for factors               =         3278071
#  INFOG (11) Maximum front size                      =            3656
#  INFOG (29) Number of entries in factors            =       230145188
#  INFOG (12) Number of off diagonal pivots           =             315
#  INFOG (13) Number of delayed pivots                =               0
#  RINFOG(19) Smallest pivot WITH perturbed pivots    = 8.401D-06
#  RINFOG(20) Smallest pivot WITHOUT perturbed pivots = 8.401D-06
#  RINFOG(21) Largest pivot in absolute value         = 7.265D+01
#  INFOG (24) Effective value of ICNTL(12)            =               1
#  INFOG (14) Number of memory compress               =              32
#  Elapsed time in factorization driver               =      1.7225
# Residual norms for GMRES solve
# Entering DMUMPS 5.7.3 from C interface with JOB, N =   3      280194
#       executing #MPI =     16 and #OMP =      1
#  ****** SOLVE & CHECK STEP ********
#  GLOBAL STATISTICS PRIOR SOLVE PHASE ...........
#  Number of right-hand-sides                    =           1
#  Blocking factor for multiple rhs              =           1
#  ICNTL (9)                                     =           1
#   --- (10)                                     =           0
#   --- (11)                                     =           0
#   --- (20)                                     =          10
#   --- (21)                                     =           1
#   --- (30)                                     =           0
#   --- (35)                                     =           0
#   --- (48) (effective)                         =           0
#  ** Rank of processor needing largest memory in solve     :        14
#  ** Space in MBYTES used by this processor for solve      :       225
#  ** Avg. Space in MBYTES per working proc during solve    :       197
#  Leaving solve with ...
#  Time to build/scatter RHS        =       0.001001
#  Time in solution step (fwd/bwd)  =       0.043758
#   .. Time in forward (fwd) step   =          0.021400
#   .. Time in ScaLAPACK root       =          0.000715
#   .. Time in backward (bwd) step  =          0.021634
#  Time to gather solution(cent.sol)=       0.000000
#  Time for distributed solution    =       0.000516
#  Elapsed time in solve driver=       0.0500
# 0 (restart 0) KSP residual norm 1.927328e+01
# Entering DMUMPS 5.7.3 from C interface with JOB, N =   3      280194
#       executing #MPI =     16 and #OMP =      1
#  ****** SOLVE & CHECK STEP ********
#  GLOBAL STATISTICS PRIOR SOLVE PHASE ...........
#  Number of right-hand-sides                    =           1
#  Blocking factor for multiple rhs              =           1
#  ICNTL (9)                                     =           1
#   --- (10)                                     =           0
#   --- (11)                                     =           0
#   --- (20)                                     =          10
#   --- (21)                                     =           1
#   --- (30)                                     =           0
#   --- (35)                                     =           0
#   --- (48) (effective)                         =           0
#  ** Rank of processor needing largest memory in solve     :        14
#  ** Space in MBYTES used by this processor for solve      :       225
#  ** Avg. Space in MBYTES per working proc during solve    :       197
#  Leaving solve with ...
#  Time to build/scatter RHS        =       0.000985
#  Time in solution step (fwd/bwd)  =       0.047096
#   .. Time in forward (fwd) step   =          0.022422
#   .. Time in ScaLAPACK root       =          0.000789
#   .. Time in backward (bwd) step  =          0.023876
#  Time to gather solution(cent.sol)=       0.000000
#  Time for distributed solution    =       0.000537
#  Elapsed time in solve driver=       0.0524
# 1 (restart 0) KSP residual norm 4.141300e-12
# GMRES solver converged in 1 iteration (avg. reduction factor: 2.149e-13)
#  Field energy E (4.615e-05 J) + H (1.867e-05 J) = 6.482e-05 J
# PCG solver did NOT converge in 0 iterations
# --> Warning!
# Linear solver did not converge, norm(Ax-b)/norm(b) = 1.000e+00 (norm(b) = 8.659e-01)!
# PCG solver did NOT converge in 0 iterations
# --> Warning!
# Linear solver did not converge, norm(Ax-b)/norm(b) = 1.000e+00 (norm(b) = 4.559e-01)!
# Entering DMUMPS 5.7.3 from C interface with JOB, N =   2      280194
#       executing #MPI =     16 and #OMP =      1
# ****** FACTORIZATION STEP ********
#  GLOBAL STATISTICS PRIOR NUMERICAL FACTORIZATION ...
#  Number of working processes                =              16
#  ICNTL(22) Out-of-core option               =               0
#  ICNTL(35) BLR activation (eff. choice)     =               0
#  ICNTL(37) BLR CB compression (eff. choice) =               0
#  ICNTL(49) Compact workarray S (end facto.) =               0
#  ICNTL(14) Memory relaxation                =              20
#  INFOG(3) Real space for factors (estimated)=       230379410
#  INFOG(4) Integer space for factors (estim.)=         3284452
#  Maximum frontal size (estimated)           =            3656
#  Number of nodes in the tree                =            9764
#  ICNTL(23) Memory allowed (value on host)   =               0
#            Sum over all procs               =               0
#  Memory provided by user, sum of LWK_USER   =               0
#  Effective threshold for pivoting, CNTL(1)  =      0.1000D-01
#  Statistics on the scaling phase
#  Elapsed time for scaling                   =      0.0617
#  Max difference from 1 after scaling the entries for ONE-NORM (option 7/8)   = 0.12D+00
#  Average Effective size of S     (based on INFO(39))=             21247472
#  Redistrib: total data local/sent           =          133265        10109161
#  Elapsed time to reformat/distribute matrix =      0.0512
#  Allocated buffers
#  ------------------
#  Size of reception buffer in bytes ...... =      5325052
#  Size of async. emission buffer (bytes).. =     10703352
#  Small emission buffer (bytes) .......... =         6720
#  ** Memory allocated, max in Mbytes             (INFOG(18)):         296
#  ** Memory allocated, total in Mbytes           (INFOG(19)):        4254
#  ** Memory effectively used, max in  Mbytes     (INFOG(21)):         265
#  ** Memory effectively used, total in Mbytes    (INFOG(22)):        3819
#  Elapsed time to process root node                  =      0.0065
#  Elapsed time for factorization                     =      1.6812
# Leaving factorization with ...
#  RINFOG (2) Operations in node assembly             = 5.032D+08
#  ------ (3) Operations in node elimination          = 3.056D+11
#  ICNTL  (8) Scaling effectively used                =               7
#  INFOG  (9) Real space for factors                  =       230145188
#  INFOG (10) Integer space for factors               =         3276078
#  INFOG (11) Maximum front size                      =            3656
#  INFOG (29) Number of entries in factors            =       230145188
#  INFOG (12) Number of off diagonal pivots           =             314
#  INFOG (13) Number of delayed pivots                =               0
#  RINFOG(19) Smallest pivot WITH perturbed pivots    = 7.800D-06
#  RINFOG(20) Smallest pivot WITHOUT perturbed pivots = 7.800D-06
#  RINFOG(21) Largest pivot in absolute value         = 5.508D+01
#  INFOG (24) Effective value of ICNTL(12)            =               1
#  INFOG (14) Number of memory compress               =              37
#  Elapsed time in factorization driver               =      1.7989
# Residual norms for GMRES solve
# Entering DMUMPS 5.7.3 from C interface with JOB, N =   3      280194
#       executing #MPI =     16 and #OMP =      1
#  ****** SOLVE & CHECK STEP ********
#  GLOBAL STATISTICS PRIOR SOLVE PHASE ...........
#  Number of right-hand-sides                    =           1
#  Blocking factor for multiple rhs              =           1
#  ICNTL (9)                                     =           1
#   --- (10)                                     =           0
#   --- (11)                                     =           0
#   --- (20)                                     =          10
#   --- (21)                                     =           1
#   --- (30)                                     =           0
#   --- (35)                                     =           0
#   --- (48) (effective)                         =           0
#  ** Rank of processor needing largest memory in solve     :        14
#  ** Space in MBYTES used by this processor for solve      :       225
#  ** Avg. Space in MBYTES per working proc during solve    :       197
#  Leaving solve with ...
#  Time to build/scatter RHS        =       0.001067
#  Time in solution step (fwd/bwd)  =       0.044103
#   .. Time in forward (fwd) step   =          0.021642
#   .. Time in ScaLAPACK root       =          0.000673
#   .. Time in backward (bwd) step  =          0.021775
#  Time to gather solution(cent.sol)=       0.000000
#  Time for distributed solution    =       0.000508
#  Elapsed time in solve driver=       0.0504
# 0 (restart 0) KSP residual norm 1.986382e+01
# Entering DMUMPS 5.7.3 from C interface with JOB, N =   3      280194
#       executing #MPI =     16 and #OMP =      1
#  ****** SOLVE & CHECK STEP ********
#  GLOBAL STATISTICS PRIOR SOLVE PHASE ...........
#  Number of right-hand-sides                    =           1
#  Blocking factor for multiple rhs              =           1
#  ICNTL (9)                                     =           1
#   --- (10)                                     =           0
#   --- (11)                                     =           0
#   --- (20)                                     =          10
#   --- (21)                                     =           1
#   --- (30)                                     =           0
#   --- (35)                                     =           0
#   --- (48) (effective)                         =           0
#  ** Rank of processor needing largest memory in solve     :        14
#  ** Space in MBYTES used by this processor for solve      :       225
#  ** Avg. Space in MBYTES per working proc during solve    :       197
#  Leaving solve with ...
#  Time to build/scatter RHS        =       0.000957
#  Time in solution step (fwd/bwd)  =       0.044545
#   .. Time in forward (fwd) step   =          0.021992
#   .. Time in ScaLAPACK root       =          0.000687
#   .. Time in backward (bwd) step  =          0.021856
#  Time to gather solution(cent.sol)=       0.000000
#  Time for distributed solution    =       0.000492
#  Elapsed time in solve driver=       0.0512
# 1 (restart 0) KSP residual norm 4.765558e-12
# GMRES solver converged in 1 iteration (avg. reduction factor: 2.399e-13)
# Greedy iteration 1 (n = 4): ω* = 1.950e+04 GHz (1.410e+01), error = 3.156e-04, memory = 1/2
#  Field energy E (4.878e-05 J) + H (1.887e-05 J) = 6.765e-05 J
# PCG solver did NOT converge in 0 iterations
# --> Warning!
# Linear solver did not converge, norm(Ax-b)/norm(b) = 1.000e+00 (norm(b) = 8.948e-01)!
# PCG solver did NOT converge in 0 iterations
# --> Warning!
# Linear solver did not converge, norm(Ax-b)/norm(b) = 1.000e+00 (norm(b) = 4.581e-01)!
# Entering DMUMPS 5.7.3 from C interface with JOB, N =   2      280194
#       executing #MPI =     16 and #OMP =      1
# ****** FACTORIZATION STEP ********
#  GLOBAL STATISTICS PRIOR NUMERICAL FACTORIZATION ...
#  Number of working processes                =              16
#  ICNTL(22) Out-of-core option               =               0
#  ICNTL(35) BLR activation (eff. choice)     =               0
#  ICNTL(37) BLR CB compression (eff. choice) =               0
#  ICNTL(49) Compact workarray S (end facto.) =               0
#  ICNTL(14) Memory relaxation                =              20
#  INFOG(3) Real space for factors (estimated)=       230379410
#  INFOG(4) Integer space for factors (estim.)=         3284452
#  Maximum frontal size (estimated)           =            3656
#  Number of nodes in the tree                =            9764
#  ICNTL(23) Memory allowed (value on host)   =               0
#            Sum over all procs               =               0
#  Memory provided by user, sum of LWK_USER   =               0
#  Effective threshold for pivoting, CNTL(1)  =      0.1000D-01
#  Statistics on the scaling phase
#  Elapsed time for scaling                   =      0.0626
#  Max difference from 1 after scaling the entries for ONE-NORM (option 7/8)   = 0.12D+00
#  Average Effective size of S     (based on INFO(39))=             21247472
#  Redistrib: total data local/sent           =          133265        10109161
#  Elapsed time to reformat/distribute matrix =      0.0435
#  Allocated buffers
#  ------------------
#  Size of reception buffer in bytes ...... =      5325052
#  Size of async. emission buffer (bytes).. =     10703352
#  Small emission buffer (bytes) .......... =         6720
#  ** Memory allocated, max in Mbytes             (INFOG(18)):         296
#  ** Memory allocated, total in Mbytes           (INFOG(19)):        4254
#  ** Memory effectively used, max in  Mbytes     (INFOG(21)):         258
#  ** Memory effectively used, total in Mbytes    (INFOG(22)):        3780
#  Elapsed time to process root node                  =      0.0063
#  Elapsed time for factorization                     =      1.5881
# Leaving factorization with ...
#  RINFOG (2) Operations in node assembly             = 5.032D+08
#  ------ (3) Operations in node elimination          = 3.056D+11
#  ICNTL  (8) Scaling effectively used                =               7
#  INFOG  (9) Real space for factors                  =       230145188
#  INFOG (10) Integer space for factors               =         3277138
#  INFOG (11) Maximum front size                      =            3656
#  INFOG (29) Number of entries in factors            =       230145188
#  INFOG (12) Number of off diagonal pivots           =             325
#  INFOG (13) Number of delayed pivots                =               0
#  RINFOG(19) Smallest pivot WITH perturbed pivots    = 8.144D-06
#  RINFOG(20) Smallest pivot WITHOUT perturbed pivots = 8.144D-06
#  RINFOG(21) Largest pivot in absolute value         = 6.121D+01
#  INFOG (24) Effective value of ICNTL(12)            =               1
#  INFOG (14) Number of memory compress               =              35
#  Elapsed time in factorization driver               =      1.6984
# Residual norms for GMRES solve
# Entering DMUMPS 5.7.3 from C interface with JOB, N =   3      280194
#       executing #MPI =     16 and #OMP =      1
#  ****** SOLVE & CHECK STEP ********
#  GLOBAL STATISTICS PRIOR SOLVE PHASE ...........
#  Number of right-hand-sides                    =           1
#  Blocking factor for multiple rhs              =           1
#  ICNTL (9)                                     =           1
#   --- (10)                                     =           0
#   --- (11)                                     =           0
#   --- (20)                                     =          10
#   --- (21)                                     =           1
#   --- (30)                                     =           0
#   --- (35)                                     =           0
#   --- (48) (effective)                         =           0
#  ** Rank of processor needing largest memory in solve     :        14
#  ** Space in MBYTES used by this processor for solve      :       225
#  ** Avg. Space in MBYTES per working proc during solve    :       197
#  Leaving solve with ...
#  Time to build/scatter RHS        =       0.001060
#  Time in solution step (fwd/bwd)  =       0.041913
#   .. Time in forward (fwd) step   =          0.020409
#   .. Time in ScaLAPACK root       =          0.000739
#   .. Time in backward (bwd) step  =          0.020756
#  Time to gather solution(cent.sol)=       0.000000
#  Time for distributed solution    =       0.000509
#  Elapsed time in solve driver=       0.0480
# 0 (restart 0) KSP residual norm 1.951740e+01
# Entering DMUMPS 5.7.3 from C interface with JOB, N =   3      280194
#       executing #MPI =     16 and #OMP =      1
#  ****** SOLVE & CHECK STEP ********
#  GLOBAL STATISTICS PRIOR SOLVE PHASE ...........
#  Number of right-hand-sides                    =           1
#  Blocking factor for multiple rhs              =           1
#  ICNTL (9)                                     =           1
#   --- (10)                                     =           0
#   --- (11)                                     =           0
#   --- (20)                                     =          10
#   --- (21)                                     =           1
#   --- (30)                                     =           0
#   --- (35)                                     =           0
#   --- (48) (effective)                         =           0
#  ** Rank of processor needing largest memory in solve     :        14
#  ** Space in MBYTES used by this processor for solve      :       225
#  ** Avg. Space in MBYTES per working proc during solve    :       197
#  Leaving solve with ...
#  Time to build/scatter RHS        =       0.001075
#  Time in solution step (fwd/bwd)  =       0.045640
#   .. Time in forward (fwd) step   =          0.023214
#   .. Time in ScaLAPACK root       =          0.000760
#   .. Time in backward (bwd) step  =          0.021655
#  Time to gather solution(cent.sol)=       0.000000
#  Time for distributed solution    =       0.000502
#  Elapsed time in solve driver=       0.0518
# 1 (restart 0) KSP residual norm 3.940156e-12
# GMRES solver converged in 1 iteration (avg. reduction factor: 2.019e-13)
# Greedy iteration 2 (n = 6): ω* = 1.979e+04 GHz (1.431e+01), error = 5.739e-06, memory = 2/2
#  Field energy E (4.723e-05 J) + H (1.875e-05 J) = 6.598e-05 J
# PCG solver did NOT converge in 0 iterations
# --> Warning!
# Linear solver did not converge, norm(Ax-b)/norm(b) = 1.000e+00 (norm(b) = 8.779e-01)!
# PCG solver did NOT converge in 0 iterations
# --> Warning!
# Linear solver did not converge, norm(Ax-b)/norm(b) = 1.000e+00 (norm(b) = 4.568e-01)!
# Adaptive sampling converged with 4 frequency samples:
#  n = 8, error = 5.739e-06, tol = 2.000e-02, memory = 2/2
#  Sampled frequencies (GHz): 1.900e+04, 2.000e+04, 1.950e+04, 1.979e+04
#  Sample errors: inf, inf, 3.156e-04, 5.739e-06
#  Total offline phase elapsed time: 1.08e+01 s
# Beginning fast frequency sweep online phase
# It 1/21: ω/2π = 1.900e+04 GHz (total elapsed time = 1.08e+01 s)
# Calculating boundary modes at wave ports for ω/2π = 1.900e+04 GHz (1.374e+01)
#  Port 1, mode 1: kₙ = 7.952e-11+8.290e+05i m⁻¹
#  Port 2, mode 1: kₙ = 0.000e+00-8.290e+05i m⁻¹
#  Port 3, mode 1: kₙ = 0.000e+00-8.290e+05i m⁻¹
#  Port 4, mode 1: kₙ = 0.000e+00-8.290e+05i m⁻¹
#  Sol. ||E|| = 2.049564e+01
#  Field energy E (5.170e-05 J) + H (1.909e-05 J) = 7.078e-05 J
#  S[1][1] = +1.246e+00-3.893e+00i, |S[1][1]| = +1.223e+01, arg(S[1][1]) = -7.225e+01
#  S[2][1] = +5.482e-02+8.850e-01i, |S[2][1]| = -1.044e+00, arg(S[2][1]) = +8.646e+01
#  S[3][1] = -2.983e-04+3.034e-04i, |S[3][1]| = -6.742e+01, arg(S[3][1]) = +1.345e+02
#  S[4][1] = -2.985e-04+3.039e-04i, |S[4][1]| = -6.741e+01, arg(S[4][1]) = +1.345e+02
# It 2/21: ω/2π = 1.905e+04 GHz (total elapsed time = 1.09e+01 s)
# Calculating boundary modes at wave ports for ω/2π = 1.905e+04 GHz (1.377e+01)
#  Port 1, mode 1: kₙ = 1.037e-11+8.285e+05i m⁻¹
#  Port 2, mode 1: kₙ = 0.000e+00-8.285e+05i m⁻¹
#  Port 3, mode 1: kₙ = 0.000e+00-8.285e+05i m⁻¹
#  Port 4, mode 1: kₙ = 0.000e+00-8.285e+05i m⁻¹
#  Sol. ||E|| = 2.043019e+01
#  Field energy E (5.139e-05 J) + H (1.906e-05 J) = 7.045e-05 J
#  S[1][1] = +1.241e+00-3.869e+00i, |S[1][1]| = +1.218e+01, arg(S[1][1]) = -7.222e+01
#  S[2][1] = +5.706e-02+8.819e-01i, |S[2][1]| = -1.073e+00, arg(S[2][1]) = +8.630e+01
#  S[3][1] = -2.907e-04+3.127e-04i, |S[3][1]| = -6.739e+01, arg(S[3][1]) = +1.329e+02
#  S[4][1] = -2.908e-04+3.132e-04i, |S[4][1]| = -6.738e+01, arg(S[4][1]) = +1.329e+02
# It 3/21: ω/2π = 1.910e+04 GHz (total elapsed time = 1.10e+01 s)
# Calculating boundary modes at wave ports for ω/2π = 1.910e+04 GHz (1.381e+01)
#  Port 1, mode 1: kₙ = 2.826e-12+8.280e+05i m⁻¹
#  Port 2, mode 1: kₙ = 0.000e+00-8.280e+05i m⁻¹
#  Port 3, mode 1: kₙ = 0.000e+00-8.280e+05i m⁻¹
#  Port 4, mode 1: kₙ = 0.000e+00-8.280e+05i m⁻¹
#  Sol. ||E|| = 2.036522e+01
#  Field energy E (5.109e-05 J) + H (1.904e-05 J) = 7.013e-05 J
#  S[1][1] = +1.236e+00-3.846e+00i, |S[1][1]| = +1.213e+01, arg(S[1][1]) = -7.219e+01
#  S[2][1] = +5.927e-02+8.788e-01i, |S[2][1]| = -1.102e+00, arg(S[2][1]) = +8.614e+01
#  S[3][1] = -2.828e-04+3.216e-04i, |S[3][1]| = -6.737e+01, arg(S[3][1]) = +1.313e+02
#  S[4][1] = -2.829e-04+3.222e-04i, |S[4][1]| = -6.736e+01, arg(S[4][1]) = +1.313e+02
# It 4/21: ω/2π = 1.915e+04 GHz (total elapsed time = 1.11e+01 s)
# Calculating boundary modes at wave ports for ω/2π = 1.915e+04 GHz (1.385e+01)
#  Port 1, mode 1: kₙ = 1.368e-11+8.274e+05i m⁻¹
#  Port 2, mode 1: kₙ = 0.000e+00-8.274e+05i m⁻¹
#  Port 3, mode 1: kₙ = 0.000e+00-8.274e+05i m⁻¹
#  Port 4, mode 1: kₙ = 0.000e+00-8.274e+05i m⁻¹
#  Sol. ||E|| = 2.030073e+01
#  Field energy E (5.079e-05 J) + H (1.902e-05 J) = 6.981e-05 J
#  S[1][1] = +1.231e+00-3.823e+00i, |S[1][1]| = +1.208e+01, arg(S[1][1]) = -7.215e+01
#  S[2][1] = +6.147e-02+8.758e-01i, |S[2][1]| = -1.131e+00, arg(S[2][1]) = +8.598e+01
#  S[3][1] = -2.746e-04+3.304e-04i, |S[3][1]| = -6.734e+01, arg(S[3][1]) = +1.297e+02
#  S[4][1] = -2.747e-04+3.309e-04i, |S[4][1]| = -6.733e+01, arg(S[4][1]) = +1.297e+02
# It 5/21: ω/2π = 1.920e+04 GHz (total elapsed time = 1.12e+01 s)
# Calculating boundary modes at wave ports for ω/2π = 1.920e+04 GHz (1.388e+01)
#  Port 1, mode 1: kₙ = 5.335e-11-8.269e+05i m⁻¹
#  Port 2, mode 1: kₙ = 0.000e+00-8.269e+05i m⁻¹
#  Port 3, mode 1: kₙ = 0.000e+00-8.269e+05i m⁻¹
#  Port 4, mode 1: kₙ = 0.000e+00-8.269e+05i m⁻¹
#  Sol. ||E|| = 2.023671e+01
#  Field energy E (5.049e-05 J) + H (1.899e-05 J) = 6.949e-05 J
#  S[1][1] = +1.226e+00-3.800e+00i, |S[1][1]| = +1.202e+01, arg(S[1][1]) = -7.212e+01
#  S[2][1] = +6.366e-02+8.727e-01i, |S[2][1]| = -1.159e+00, arg(S[2][1]) = +8.583e+01
#  S[3][1] = -2.661e-04+3.389e-04i, |S[3][1]| = -6.731e+01, arg(S[3][1]) = +1.281e+02
#  S[4][1] = -2.662e-04+3.395e-04i, |S[4][1]| = -6.730e+01, arg(S[4][1]) = +1.281e+02
# It 6/21: ω/2π = 1.925e+04 GHz (total elapsed time = 1.14e+01 s)
# Calculating boundary modes at wave ports for ω/2π = 1.925e+04 GHz (1.392e+01)
#  Port 1, mode 1: kₙ = 1.652e-11-8.264e+05i m⁻¹
#  Port 2, mode 1: kₙ = 0.000e+00-8.264e+05i m⁻¹
#  Port 3, mode 1: kₙ = 0.000e+00-8.264e+05i m⁻¹
#  Port 4, mode 1: kₙ = 0.000e+00-8.264e+05i m⁻¹
#  Sol. ||E|| = 2.017315e+01
#  Field energy E (5.020e-05 J) + H (1.897e-05 J) = 6.917e-05 J
#  S[1][1] = +1.221e+00-3.777e+00i, |S[1][1]| = +1.197e+01, arg(S[1][1]) = -7.209e+01
#  S[2][1] = +6.582e-02+8.697e-01i, |S[2][1]| = -1.188e+00, arg(S[2][1]) = +8.567e+01
#  S[3][1] = -2.574e-04+3.472e-04i, |S[3][1]| = -6.729e+01, arg(S[3][1]) = +1.265e+02
#  S[4][1] = -2.575e-04+3.477e-04i, |S[4][1]| = -6.728e+01, arg(S[4][1]) = +1.265e+02
# It 7/21: ω/2π = 1.930e+04 GHz (total elapsed time = 1.15e+01 s)
# Calculating boundary modes at wave ports for ω/2π = 1.930e+04 GHz (1.396e+01)
#  Port 1, mode 1: kₙ = 4.296e-11-8.258e+05i m⁻¹
#  Port 2, mode 1: kₙ = 0.000e+00-8.258e+05i m⁻¹
#  Port 3, mode 1: kₙ = 0.000e+00-8.258e+05i m⁻¹
#  Port 4, mode 1: kₙ = 0.000e+00-8.258e+05i m⁻¹
#  Sol. ||E|| = 2.011005e+01
#  Field energy E (4.991e-05 J) + H (1.895e-05 J) = 6.886e-05 J
#  S[1][1] = +1.216e+00-3.754e+00i, |S[1][1]| = +1.192e+01, arg(S[1][1]) = -7.205e+01
#  S[2][1] = +6.798e-02+8.667e-01i, |S[2][1]| = -1.216e+00, arg(S[2][1]) = +8.552e+01
#  S[3][1] = -2.484e-04+3.552e-04i, |S[3][1]| = -6.726e+01, arg(S[3][1]) = +1.250e+02
#  S[4][1] = -2.485e-04+3.558e-04i, |S[4][1]| = -6.725e+01, arg(S[4][1]) = +1.249e+02
# It 8/21: ω/2π = 1.935e+04 GHz (total elapsed time = 1.16e+01 s)
# Calculating boundary modes at wave ports for ω/2π = 1.935e+04 GHz (1.399e+01)
#  Port 1, mode 1: kₙ = 3.424e-11-8.253e+05i m⁻¹
#  Port 2, mode 1: kₙ = 0.000e+00-8.253e+05i m⁻¹
#  Port 3, mode 1: kₙ = 0.000e+00-8.253e+05i m⁻¹
#  Port 4, mode 1: kₙ = 0.000e+00-8.253e+05i m⁻¹
#  Sol. ||E|| = 2.004742e+01
#  Field energy E (4.962e-05 J) + H (1.893e-05 J) = 6.855e-05 J
#  S[1][1] = +1.211e+00-3.732e+00i, |S[1][1]| = +1.187e+01, arg(S[1][1]) = -7.202e+01
#  S[2][1] = +7.011e-02+8.637e-01i, |S[2][1]| = -1.244e+00, arg(S[2][1]) = +8.536e+01
#  S[3][1] = -2.392e-04+3.630e-04i, |S[3][1]| = -6.724e+01, arg(S[3][1]) = +1.234e+02
#  S[4][1] = -2.393e-04+3.636e-04i, |S[4][1]| = -6.723e+01, arg(S[4][1]) = +1.233e+02
# It 9/21: ω/2π = 1.940e+04 GHz (total elapsed time = 1.18e+01 s)
# Calculating boundary modes at wave ports for ω/2π = 1.940e+04 GHz (1.403e+01)
#  Port 1, mode 1: kₙ = 6.996e-11-8.247e+05i m⁻¹
#  Port 2, mode 1: kₙ = 0.000e+00-8.247e+05i m⁻¹
#  Port 3, mode 1: kₙ = 0.000e+00-8.247e+05i m⁻¹
#  Port 4, mode 1: kₙ = 0.000e+00-8.247e+05i m⁻¹
#  Sol. ||E|| = 1.998524e+01
#  Field energy E (4.934e-05 J) + H (1.891e-05 J) = 6.824e-05 J
#  S[1][1] = +1.206e+00-3.709e+00i, |S[1][1]| = +1.182e+01, arg(S[1][1]) = -7.198e+01
#  S[2][1] = +7.223e-02+8.607e-01i, |S[2][1]| = -1.272e+00, arg(S[2][1]) = +8.520e+01
#  S[3][1] = -2.297e-04+3.706e-04i, |S[3][1]| = -6.721e+01, arg(S[3][1]) = +1.218e+02
#  S[4][1] = -2.298e-04+3.711e-04i, |S[4][1]| = -6.720e+01, arg(S[4][1]) = +1.218e+02
# It 10/21: ω/2π = 1.945e+04 GHz (total elapsed time = 1.19e+01 s)
# Calculating boundary modes at wave ports for ω/2π = 1.945e+04 GHz (1.406e+01)
#  Port 1, mode 1: kₙ = 2.553e-11-8.242e+05i m⁻¹
#  Port 2, mode 1: kₙ = 0.000e+00-8.242e+05i m⁻¹
#  Port 3, mode 1: kₙ = 0.000e+00-8.242e+05i m⁻¹
#  Port 4, mode 1: kₙ = 0.000e+00-8.242e+05i m⁻¹
#  Sol. ||E|| = 1.992351e+01
#  Field energy E (4.906e-05 J) + H (1.889e-05 J) = 6.794e-05 J
#  S[1][1] = +1.202e+00-3.687e+00i, |S[1][1]| = +1.177e+01, arg(S[1][1]) = -7.195e+01
#  S[2][1] = +7.434e-02+8.577e-01i, |S[2][1]| = -1.300e+00, arg(S[2][1]) = +8.505e+01
#  S[3][1] = -2.200e-04+3.779e-04i, |S[3][1]| = -6.719e+01, arg(S[3][1]) = +1.202e+02
#  S[4][1] = -2.200e-04+3.784e-04i, |S[4][1]| = -6.718e+01, arg(S[4][1]) = +1.202e+02
# It 11/21: ω/2π = 1.950e+04 GHz (total elapsed time = 1.20e+01 s)
# Calculating boundary modes at wave ports for ω/2π = 1.950e+04 GHz (1.410e+01)
#  Port 1, mode 1: kₙ = 5.627e-11-8.237e+05i m⁻¹
#  Port 2, mode 1: kₙ = 0.000e+00-8.237e+05i m⁻¹
#  Port 3, mode 1: kₙ = 0.000e+00-8.237e+05i m⁻¹
#  Port 4, mode 1: kₙ = 0.000e+00-8.237e+05i m⁻¹
#  Sol. ||E|| = 1.986223e+01
#  Field energy E (4.878e-05 J) + H (1.887e-05 J) = 6.764e-05 J
#  S[1][1] = +1.197e+00-3.665e+00i, |S[1][1]| = +1.172e+01, arg(S[1][1]) = -7.191e+01
#  S[2][1] = +7.643e-02+8.548e-01i, |S[2][1]| = -1.328e+00, arg(S[2][1]) = +8.489e+01
#  S[3][1] = -2.101e-04+3.849e-04i, |S[3][1]| = -6.716e+01, arg(S[3][1]) = +1.186e+02
#  S[4][1] = -2.101e-04+3.855e-04i, |S[4][1]| = -6.715e+01, arg(S[4][1]) = +1.186e+02
# It 12/21: ω/2π = 1.955e+04 GHz (total elapsed time = 1.21e+01 s)
# Calculating boundary modes at wave ports for ω/2π = 1.955e+04 GHz (1.414e+01)
#  Port 1, mode 1: kₙ = 8.546e-12+8.231e+05i m⁻¹
#  Port 2, mode 1: kₙ = 0.000e+00-8.231e+05i m⁻¹
#  Port 3, mode 1: kₙ = 0.000e+00-8.231e+05i m⁻¹
#  Port 4, mode 1: kₙ = 0.000e+00-8.231e+05i m⁻¹
#  Sol. ||E|| = 1.980139e+01
#  Field energy E (4.850e-05 J) + H (1.884e-05 J) = 6.735e-05 J
#  S[1][1] = +1.192e+00-3.643e+00i, |S[1][1]| = +1.167e+01, arg(S[1][1]) = -7.188e+01
#  S[2][1] = +7.851e-02+8.518e-01i, |S[2][1]| = -1.356e+00, arg(S[2][1]) = +8.473e+01
#  S[3][1] = -1.999e-04+3.917e-04i, |S[3][1]| = -6.713e+01, arg(S[3][1]) = +1.170e+02
#  S[4][1] = -1.999e-04+3.923e-04i, |S[4][1]| = -6.713e+01, arg(S[4][1]) = +1.170e+02
# It 13/21: ω/2π = 1.960e+04 GHz (total elapsed time = 1.22e+01 s)
# Calculating boundary modes at wave ports for ω/2π = 1.960e+04 GHz (1.417e+01)
#  Port 1, mode 1: kₙ = 7.044e-11-8.226e+05i m⁻¹
#  Port 2, mode 1: kₙ = 0.000e+00-8.226e+05i m⁻¹
#  Port 3, mode 1: kₙ = 0.000e+00-8.226e+05i m⁻¹
#  Port 4, mode 1: kₙ = 0.000e+00-8.226e+05i m⁻¹
#  Sol. ||E|| = 1.974099e+01
#  Field energy E (4.823e-05 J) + H (1.882e-05 J) = 6.705e-05 J
#  S[1][1] = +1.188e+00-3.621e+00i, |S[1][1]| = +1.162e+01, arg(S[1][1]) = -7.184e+01
#  S[2][1] = +8.057e-02+8.489e-01i, |S[2][1]| = -1.384e+00, arg(S[2][1]) = +8.458e+01
#  S[3][1] = -1.895e-04+3.983e-04i, |S[3][1]| = -6.711e+01, arg(S[3][1]) = +1.154e+02
#  S[4][1] = -1.895e-04+3.988e-04i, |S[4][1]| = -6.710e+01, arg(S[4][1]) = +1.154e+02
# It 14/21: ω/2π = 1.965e+04 GHz (total elapsed time = 1.24e+01 s)
# Calculating boundary modes at wave ports for ω/2π = 1.965e+04 GHz (1.421e+01)
#  Port 1, mode 1: kₙ = 1.761e-11-8.220e+05i m⁻¹
#  Port 2, mode 1: kₙ = 0.000e+00-8.220e+05i m⁻¹
#  Port 3, mode 1: kₙ = 0.000e+00-8.220e+05i m⁻¹
#  Port 4, mode 1: kₙ = 0.000e+00-8.220e+05i m⁻¹
#  Sol. ||E|| = 1.968104e+01
#  Field energy E (4.796e-05 J) + H (1.880e-05 J) = 6.676e-05 J
#  S[1][1] = +1.183e+00-3.600e+00i, |S[1][1]| = +1.157e+01, arg(S[1][1]) = -7.180e+01
#  S[2][1] = +8.262e-02+8.460e-01i, |S[2][1]| = -1.411e+00, arg(S[2][1]) = +8.442e+01
#  S[3][1] = -1.790e-04+4.046e-04i, |S[3][1]| = -6.708e+01, arg(S[3][1]) = +1.139e+02
#  S[4][1] = -1.789e-04+4.051e-04i, |S[4][1]| = -6.707e+01, arg(S[4][1]) = +1.138e+02
# It 15/21: ω/2π = 1.970e+04 GHz (total elapsed time = 1.25e+01 s)
# Calculating boundary modes at wave ports for ω/2π = 1.970e+04 GHz (1.424e+01)
#  Port 1, mode 1: kₙ = 2.515e-11-8.214e+05i m⁻¹
#  Port 2, mode 1: kₙ = 0.000e+00-8.214e+05i m⁻¹
#  Port 3, mode 1: kₙ = 0.000e+00-8.214e+05i m⁻¹
#  Port 4, mode 1: kₙ = 0.000e+00-8.214e+05i m⁻¹
#  Sol. ||E|| = 1.962151e+01
#  Field energy E (4.769e-05 J) + H (1.878e-05 J) = 6.648e-05 J
#  S[1][1] = +1.179e+00-3.578e+00i, |S[1][1]| = +1.152e+01, arg(S[1][1]) = -7.177e+01
#  S[2][1] = +8.465e-02+8.431e-01i, |S[2][1]| = -1.439e+00, arg(S[2][1]) = +8.427e+01
#  S[3][1] = -1.682e-04+4.107e-04i, |S[3][1]| = -6.706e+01, arg(S[3][1]) = +1.123e+02
#  S[4][1] = -1.681e-04+4.112e-04i, |S[4][1]| = -6.705e+01, arg(S[4][1]) = +1.122e+02
# It 16/21: ω/2π = 1.975e+04 GHz (total elapsed time = 1.26e+01 s)
# Calculating boundary modes at wave ports for ω/2π = 1.975e+04 GHz (1.428e+01)
#  Port 1, mode 1: kₙ = 9.916e-12+8.209e+05i m⁻¹
#  Port 2, mode 1: kₙ = 0.000e+00-8.209e+05i m⁻¹
#  Port 3, mode 1: kₙ = 0.000e+00-8.209e+05i m⁻¹
#  Port 4, mode 1: kₙ = 0.000e+00-8.209e+05i m⁻¹
#  Sol. ||E|| = 1.956241e+01
#  Field energy E (4.743e-05 J) + H (1.876e-05 J) = 6.619e-05 J
#  S[1][1] = +1.174e+00-3.557e+00i, |S[1][1]| = +1.147e+01, arg(S[1][1]) = -7.173e+01
#  S[2][1] = +8.667e-02+8.403e-01i, |S[2][1]| = -1.466e+00, arg(S[2][1]) = +8.411e+01
#  S[3][1] = -1.574e-04+4.171e-04i, |S[3][1]| = -6.702e+01, arg(S[3][1]) = +1.107e+02
#  S[4][1] = -1.573e-04+4.177e-04i, |S[4][1]| = -6.701e+01, arg(S[4][1]) = +1.106e+02
# It 17/21: ω/2π = 1.980e+04 GHz (total elapsed time = 1.28e+01 s)
# Calculating boundary modes at wave ports for ω/2π = 1.980e+04 GHz (1.432e+01)
#  Port 1, mode 1: kₙ = 1.931e-11-8.203e+05i m⁻¹
#  Port 2, mode 1: kₙ = 0.000e+00-8.203e+05i m⁻¹
#  Port 3, mode 1: kₙ = 0.000e+00-8.203e+05i m⁻¹
#  Port 4, mode 1: kₙ = 0.000e+00-8.203e+05i m⁻¹
#  Sol. ||E|| = 1.950375e+01
#  Field energy E (4.717e-05 J) + H (1.875e-05 J) = 6.591e-05 J
#  S[1][1] = +1.170e+00-3.536e+00i, |S[1][1]| = +1.142e+01, arg(S[1][1]) = -7.169e+01
#  S[2][1] = +8.868e-02+8.374e-01i, |S[2][1]| = -1.493e+00, arg(S[2][1]) = +8.395e+01
#  S[3][1] = -1.462e-04+4.227e-04i, |S[3][1]| = -6.699e+01, arg(S[3][1]) = +1.091e+02
#  S[4][1] = -1.461e-04+4.232e-04i, |S[4][1]| = -6.698e+01, arg(S[4][1]) = +1.090e+02
# It 18/21: ω/2π = 1.985e+04 GHz (total elapsed time = 1.29e+01 s)
# Calculating boundary modes at wave ports for ω/2π = 1.985e+04 GHz (1.435e+01)
#  Port 1, mode 1: kₙ = 1.810e-11+8.198e+05i m⁻¹
#  Port 2, mode 1: kₙ = 0.000e+00-8.198e+05i m⁻¹
#  Port 3, mode 1: kₙ = 0.000e+00-8.198e+05i m⁻¹
#  Port 4, mode 1: kₙ = 0.000e+00-8.198e+05i m⁻¹
#  Sol. ||E|| = 1.944550e+01
#  Field energy E (4.691e-05 J) + H (1.873e-05 J) = 6.563e-05 J
#  S[1][1] = +1.165e+00-3.515e+00i, |S[1][1]| = +1.137e+01, arg(S[1][1]) = -7.165e+01
#  S[2][1] = +9.067e-02+8.346e-01i, |S[2][1]| = -1.520e+00, arg(S[2][1]) = +8.380e+01
#  S[3][1] = -1.349e-04+4.280e-04i, |S[3][1]| = -6.696e+01, arg(S[3][1]) = +1.075e+02
#  S[4][1] = -1.347e-04+4.285e-04i, |S[4][1]| = -6.695e+01, arg(S[4][1]) = +1.075e+02
# It 19/21: ω/2π = 1.990e+04 GHz (total elapsed time = 1.30e+01 s)
# Calculating boundary modes at wave ports for ω/2π = 1.990e+04 GHz (1.439e+01)
#  Port 1, mode 1: kₙ = 5.765e-11-8.192e+05i m⁻¹
#  Port 2, mode 1: kₙ = 0.000e+00-8.192e+05i m⁻¹
#  Port 3, mode 1: kₙ = 0.000e+00-8.192e+05i m⁻¹
#  Port 4, mode 1: kₙ = 1.104e-13-8.192e+05i m⁻¹
#  Sol. ||E|| = 1.938768e+01
#  Field energy E (4.665e-05 J) + H (1.871e-05 J) = 6.536e-05 J
#  S[1][1] = +1.161e+00-3.494e+00i, |S[1][1]| = +1.132e+01, arg(S[1][1]) = -7.162e+01
#  S[2][1] = +9.265e-02+8.317e-01i, |S[2][1]| = -1.547e+00, arg(S[2][1]) = +8.364e+01
#  S[3][1] = -1.233e-04+4.331e-04i, |S[3][1]| = -6.693e+01, arg(S[3][1]) = +1.059e+02
#  S[4][1] = -1.232e-04+4.336e-04i, |S[4][1]| = -6.692e+01, arg(S[4][1]) = +1.059e+02
# It 20/21: ω/2π = 1.995e+04 GHz (total elapsed time = 1.31e+01 s)
# Calculating boundary modes at wave ports for ω/2π = 1.995e+04 GHz (1.443e+01)
#  Port 1, mode 1: kₙ = 1.784e-11+8.186e+05i m⁻¹
#  Port 2, mode 1: kₙ = 0.000e+00-8.186e+05i m⁻¹
#  Port 3, mode 1: kₙ = 0.000e+00-8.186e+05i m⁻¹
#  Port 4, mode 1: kₙ = 1.289e-12+8.186e+05i m⁻¹
#  Sol. ||E|| = 1.933027e+01
#  Field energy E (4.640e-05 J) + H (1.869e-05 J) = 6.509e-05 J
#  S[1][1] = +1.157e+00-3.473e+00i, |S[1][1]| = +1.127e+01, arg(S[1][1]) = -7.158e+01
#  S[2][1] = +9.462e-02+8.289e-01i, |S[2][1]| = -1.574e+00, arg(S[2][1]) = +8.349e+01
#  S[3][1] = -1.116e-04+4.379e-04i, |S[3][1]| = -6.690e+01, arg(S[3][1]) = +1.043e+02
#  S[4][1] = -1.115e-04+4.384e-04i, |S[4][1]| = -6.689e+01, arg(S[4][1]) = +1.043e+02
# It 21/21: ω/2π = 2.000e+04 GHz (total elapsed time = 1.33e+01 s)
# Calculating boundary modes at wave ports for ω/2π = 2.000e+04 GHz (1.446e+01)
#  Port 1, mode 1: kₙ = 3.223e-11-8.181e+05i m⁻¹
#  Port 2, mode 1: kₙ = 0.000e+00-8.181e+05i m⁻¹
#  Port 3, mode 1: kₙ = 0.000e+00-8.181e+05i m⁻¹
#  Port 4, mode 1: kₙ = 5.156e-12+8.181e+05i m⁻¹
#  Sol. ||E|| = 1.927328e+01
#  Field energy E (4.615e-05 J) + H (1.867e-05 J) = 6.482e-05 J
#  S[1][1] = +1.153e+00-3.453e+00i, |S[1][1]| = +1.122e+01, arg(S[1][1]) = -7.154e+01
#  S[2][1] = +9.657e-02+8.261e-01i, |S[2][1]| = -1.600e+00, arg(S[2][1]) = +8.333e+01
#  S[3][1] = -9.979e-05+4.424e-04i, |S[3][1]| = -6.687e+01, arg(S[3][1]) = +1.027e+02
#  S[4][1] = -9.963e-05+4.429e-04i, |S[4][1]| = -6.686e+01, arg(S[4][1]) = +1.027e+02
# Entering DMUMPS 5.7.3 from C interface with JOB =  -2
#       executing #MPI =     16 and #OMP =      1
# Completed 0 iterations of adaptive mesh refinement (AMR):
#  Indicator norm = 1.000e+00, global unknowns = 140097
#  Max. iterations = 0, tol. = 1.000e-02
# Elapsed Time Report (s)           Min.        Max.        Avg.
# ==============================================================
# Initialization                   0.076       0.077       0.077
#   Mesh Preprocessing             0.705       0.705       0.705
# Operator Construction            0.523       0.553       0.541
#   Wave Ports                     2.120       2.127       2.125
# Linear Solve                     0.047       0.059       0.055
#   Setup                          9.557       9.570       9.561
#   Preconditioner                 0.435       0.466       0.449
# PROM Construction                0.059       0.064       0.060
# PROM Solve                       0.003       0.003       0.003
# Estimation                       0.031       0.035       0.032
#   Construction                   0.295       0.295       0.295
#   Solve                          0.031       0.036       0.034
# Postprocessing                   0.725       0.729       0.725
# Disk IO                          1.042       1.042       1.042
# --------------------------------------------------------------
# Total                           15.798      15.798      15.798
# Simulation completed successfully
# Results saved to palace-sim-dc-waveport/output/palace

# %% [markdown]
# ### Plot S-parameters

# %%
results.plot_interactive()
# Out:
# Port mapping: Port 1: p1, Port 2: p2, Port 3: p3, Port 4: p4

# %%
results.plot_interactive(phase=True)
# Out:
# Port mapping: Port 1: p1, Port 2: p2, Port 3: p3, Port 4: p4
